# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("../property_data.csv")
data.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0     PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0   BERKELEY           12            1      NaN   700
# 4          NaN   203.0   BERKELEY            Y            3        2  1600

# %%
    data.dtypes
# Out:
# PID             float64
# ST_NUM          float64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS     object
# NUM_BATH         object
# SQ_FT            object
# dtype: object

# %%
data['ST_NUM'].isnull().sum()
# Out:
# 2

# %%
data['ST_NUM'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: ST_NUM, dtype: bool

# %%
print(data['NUM_BEDROOMS'])
# Out:
# 0      3
# 1      3
# 2    NaN
# 3      1
# 4      3
# 5    NaN
# 6      2
# 7      1
# 8     na
# Name: NUM_BEDROOMS, dtype: object

# %%
data['NUM_BEDROOMS'].value_counts()
# Out:
# 3     3
# 1     2
# na    1
# 2     1
# Name: NUM_BEDROOMS, dtype: int64

# %%
missing_values=['NAN','na','--']
property_data=pd.read_csv("../property_data.csv",na_values=missing_values)

# %%
property_data.head(10)
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
property_data['NUM_BEDROOMS'].value_counts()
# Out:
# 3.0    3
# 1.0    2
# 2.0    1
# Name: NUM_BEDROOMS, dtype: int64

# %%
property_data['NUM_BEDROOMS'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: NUM_BEDROOMS, dtype: bool

# %%
data.isnull().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    1
# NUM_BEDROOMS    2
# NUM_BATH        1
# SQ_FT           1
# dtype: int64

# %%
kidney=pd.read_csv("../kidney.csv")

# %%
kidney.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
kidney.isnull()
# Out:
#         id    age     bp     sg     al     su    rbc     pc    pcc     ba  \
# 0    False  False  False  False  False  False   True  False  False  False
# 1    False  False  False  False  False  False   True  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  False  False  False  False  False  False  False  False  False  False
# 396  False  False  False  False  False  False  False  False  False  False
# 397  False  False  False  False  False  False  False  False  False  False
# 398  False  False  False  False  False  False  False  False  False  False
# 399  False  False  False  False  False  False  False  False  False  False
#
#      ...    pcv     wc     rc    htn     dm    cad  appet     pe    ane  \
# ...

# %%
kidney.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
kidney.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-7ebc7ef56320> in <module>
# ----> 1 kidney.value_counts()
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
happy=pd.read_csv("../world_happiness_2016.csv")
happy.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
happy.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
happy.head(20)
# Out:
#           Country                           Region  Happiness Rank  \
# 0         Denmark                   Western Europe               1
# 1     Switzerland                   Western Europe               2
# 2         Iceland                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4         Finland                   Western Europe               5
# 5          Canada                    North America               6
# 6     Netherlands                   Western Europe               7
# 7     New Zealand        Australia and New Zealand               8
# 8       Australia        Australia and New Zealand               9
# 9          Sweden                   Western Europe              10
# 10         Israel  Middle East and Northern Africa              11
# 11        Austria                   Western Europe              12
# 12  United States                    North America              13
# ...

# %%
print(data['ST_NUM'])
# Out:
# 0    104.0
# 1    197.0
# 2      NaN
# 3    201.0
# 4    203.0
# 5    207.0
# 6      NaN
# 7    213.0
# 8    215.0
# Name: ST_NUM, dtype: float64

# %%
print(data['ST_NUM'].isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: ST_NUM, dtype: bool

# %%
print(data.isnull())
# Out:
#      PID  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0  False   False    False         False         False     False  False
# 1  False   False    False         False         False     False  False
# 2  False    True    False         False          True     False  False
# 3  False   False    False         False         False      True  False
# 4   True   False    False         False         False     False  False
# 5  False   False    False         False          True     False  False
# 6  False    True    False          True         False     False  False
# 7  False   False    False         False         False     False   True
# 8  False   False    False         False         False     False  False

# %%
data[]
# Out:
# array([[100001000.0, 104.0, 'PUTNAM', 'Y', '3', '1', '1000'],
#        [100002000.0, 197.0, 'LEXINGTON', 'N', '3', '1.5', '--'],
#        [100003000.0, nan, 'LEXINGTON', 'N', nan, '1', '850'],
#        [100004000.0, 201.0, 'BERKELEY', '12', '1', nan, '700'],
#        [nan, 203.0, 'BERKELEY', 'Y', '3', '2', '1600'],
#        [100006000.0, 207.0, 'BERKELEY', 'Y', nan, '1', '800'],
#        [100007000.0, nan, 'WASHINGTON', nan, '2', 'HURLEY', '950'],
#        [100008000.0, 213.0, 'TREMONT', 'Y', '1', '1', nan],
#        [100009000.0, 215.0, 'TREMONT', 'Y', 'na', '2', '1800']],
#       dtype=object)

# %%
data['NUM_BEDROOMS'].value_counts()
# Out:
# 3     3
# 1     2
# 2     1
# na    1
# Name: NUM_BEDROOMS, dtype: int64

# %%
data['PID'].value_counts()
# Out:
# 100003000.0    1
# 100009000.0    1
# 100001000.0    1
# 100007000.0    1
# 100004000.0    1
# 100008000.0    1
# 100002000.0    1
# 100006000.0    1
# Name: PID, dtype: int64

# %%
missing_val=['Nan','na',"--"]
mis_data=pd.read_csv('../property_data.csv',na_values=missing_val)
print(mis_data)
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
print(mis_data['SQ_FT'].value_counts())
# Out:
# 1800.0    1
# 950.0     1
# 800.0     1
# 1600.0    1
# 700.0     1
# 850.0     1
# 1000.0    1
# Name: SQ_FT, dtype: int64

# %%
print(data['SQ_FT'].value_counts())
# Out:
# 1600    1
# 800     1
# 1800    1
# 850     1
# 950     1
# 700     1
# --      1
# 1000    1
# Name: SQ_FT, dtype: int64

# %%
print(mis_data['SQ_FT'])
# Out:
# 0    1000.0
# 1       NaN
# 2     850.0
# 3     700.0
# 4    1600.0
# 5     800.0
# 6     950.0
# 7       NaN
# 8    1800.0
# Name: SQ_FT, dtype: float64

# %%
print(mis_data['SQ_FT'].isnull())
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# Name: SQ_FT, dtype: bool

# %%
data['SQ_FT'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# Name: SQ_FT, dtype: bool

# %%
data.loc[0,'OWN_OCCUPIED']
# Out:
# 'Y'

# %%
data['OWN_OCCUPIED']
# Out:
# 0      Y
# 1      N
# 2      N
# 3     12
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: OWN_OCCUPIED, dtype: object

# %%
count=0
for row in data['OWN_OCCUPIED']:
    print(row)
    try:
        int(row)
        data.loc[count,'OWN_OCCUPIED']=np.nan
    except ValueError:
        pass
    count=count+1
# Out:
# Y
# N
# N
# nan
# Y
# Y
# nan
# Y
# Y

# %%
data['OWN_OCCUPIED'].value_counts()
# Out:
# Y    5
# N    2
# Name: OWN_OCCUPIED, dtype: int64

# %%
happy.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
happy.isnull().values.any()
# Out:
# False

# %%
happy.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
happy['Happiness Rank'].value_counts()
# Out:
# 57     2
# 145    2
# 34     2
# 56     1
# 55     1
#       ..
# 103    1
# 102    1
# 101    1
# 100    1
# 1      1
# Name: Happiness Rank, Length: 154, dtype: int64

# %%
missing_val=['Nan','na',"--"]
happy_data=pd.read_csv('../world_happiness_2016.csv',na_values=missing_val)
print(happy_data)
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
happy_data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0     PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0   BERKELEY          NaN            1      NaN   700
# 4          NaN   203.0   BERKELEY            Y            3        2  1600

# %%
data['PID'].fillna('missing',inplace=True)

# %%
data['PID']
# Out:
# 0    1.00001e+08
# 1    1.00002e+08
# 2    1.00003e+08
# 3    1.00004e+08
# 4        missing
# 5    1.00006e+08
# 6    1.00007e+08
# 7    1.00008e+08
# 8    1.00009e+08
# Name: PID, dtype: object

# %%
data.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  1.00001e+08   104.0     PUTNAM            Y            3        1  1000
# 1  1.00002e+08   197.0  LEXINGTON            N            3      1.5    --
# 2  1.00003e+08     NaN  LEXINGTON            N          NaN        1   850
# 3  1.00004e+08   201.0   BERKELEY          NaN            1      NaN   700
# 4      missing   203.0   BERKELEY            Y            3        2  1600

# %%
data['OWN_OCCUPIED'].fillna('125',inplace=True)

# %%
data.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  1.00001e+08   104.0     PUTNAM            Y            3        1  1000
# 1  1.00002e+08   197.0  LEXINGTON            N            3      1.5    --
# 2  1.00003e+08     NaN  LEXINGTON            N          NaN        1   850
# 3  1.00004e+08   201.0   BERKELEY          125            1      NaN   700
# 4      missing   203.0   BERKELEY            Y            3        2  1600

# %%
median=data['NUM_BEDROOMS'].median()
print(median)
data['NUM_BEDROOMS'].fillna(median,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# D:\Anaconda\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     599     if not is_float_dtype(values):
# --> 600         values = values.astype("f8")
#     601         if mask is not None:
#
# TypeError: float() argument must be a string or a number, not 'method'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-14c56856c59c> in <module>
# ----> 1 median=data['NUM_BEDROOMS'].median()
#       2 print(median)
# ...

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-71-dbd883db58b7> in <module>
# ----> 1 print(data)
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __repr__(self)
#     653             max_cols=max_cols,
#     654             line_width=width,
# --> 655             show_dimensions=show_dimensions,
#     656         )
#     657
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width)
#     759             line_width=line_width,
#     760         )
# --> 761         formatter.to_string()
#     762
#     763         if buf is None:
#
# D:\Anaconda\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     686         else:
#     687
# ...
